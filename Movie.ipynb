# %% [markdown]
# <a href="https://colab.research.google.com/github/ihska/codsoft/blob/main/Movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df= pd .read_csv('/content/Movie.zip',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df.drop(['Name','Year','Duration','Votes'], axis=1,inplace=True)

# %%
df.head()
# Out:
#              Genre    Rating            Director       Actor 1  \
# 0            Drama  5.841621       J.S. Randhawa      Manmauji
# 1            Drama  7.000000       Gaurav Bakshi  Rasika Dugal
# 2   Drama, Musical  5.841621  Soumyajit Majumdar  Sayani Gupta
# 3  Comedy, Romance  4.400000          Ovais Khan       Prateik
# 4            Drama  5.841621        Amol Palekar  Rajat Kapoor
#
#               Actor 2          Actor 3
# 0              Birbal  Rajendra Bhatia
# 1      Vivek Ghamande    Arvind Jangid
# 2   Plabita Borthakur       Roy Angana
# 3          Ishita Raj  Siddhant Kapoor
# 4  Rituparna Sengupta      Antara Mali

# %%
inputs = df.drop('Rating',axis=1)
target = df.Rating

# %%
inputs
# Out:
#                  Genre            Director           Actor 1  \
# 0                Drama       J.S. Randhawa          Manmauji
# 1                Drama       Gaurav Bakshi      Rasika Dugal
# 2       Drama, Musical  Soumyajit Majumdar      Sayani Gupta
# 3      Comedy, Romance          Ovais Khan           Prateik
# 4                Drama        Amol Palekar      Rajat Kapoor
# ...                ...                 ...               ...
# 15504           Action       Mahendra Shah  Naseeruddin Shah
# 15505    Action, Drama          Kuku Kohli      Akshay Kumar
# 15506           Action          Kiran Thej   Sangeeta Tiwari
# 15507           Action                 NaN               NaN
# 15508    Action, Drama        K.C. Bokadia        Dharmendra
#
#                   Actor 2          Actor 3
# 0                  Birbal  Rajendra Bhatia
# 1          Vivek Ghamande    Arvind Jangid
# 2       Plabita Borthakur       Roy Angana
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
target
# Out:
# 0        5.841621
# 1        7.000000
# 2        5.841621
# 3        4.400000
# 4        5.841621
#            ...
# 15504    4.600000
# 15505    4.500000
# 15506    5.841621
# 15507    5.841621
# 15508    6.200000
# Name: Rating, Length: 15509, dtype: float64

# %%
df.Rating=df.Rating.fillna(df.Rating.mean())

# %%
df['Rating'].isnull().values.any()
# Out:
# False

# %%
df.isnull()
# Out:
#        Genre  Rating  Director  Actor 1  Actor 2  Actor 3
# 0      False   False     False    False    False    False
# 1      False   False     False    False    False    False
# 2      False   False     False    False    False    False
# 3      False   False     False    False    False    False
# 4      False   False     False    False    False    False
# ...      ...     ...       ...      ...      ...      ...
# 15504  False   False     False    False    False    False
# 15505  False   False     False    False    False    False
# 15506  False   False     False    False     True     True
# 15507  False   False      True     True     True     True
# 15508  False   False     False    False    False    False
#
# [15509 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.isna().sum()
# Out:
# Genre       1877
# Rating         0
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
import seaborn as sns

# %%
df.plot.hist(bins=10)
plt.xlabel("Genre")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %%
df.plot.hist(bins=10)
plt.xlabel("Genre")
plt.ylabel("Actor 1")
# Out:
# Text(0, 0.5, 'Actor 1')

# %%
sns.barplot(x=df['Director'],y=df['Rating'])
# Out:
# <Axes: xlabel='Director', ylabel='Rating'>
